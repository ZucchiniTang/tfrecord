# %%
# %matplotlib inline
from PIL import Image
import numpy as np
import skimage.io as io 
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# /home/qing/anaconda3/envs/py35_qt4/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
anno_files = '/media/qing/linux/repo/TF_detection_API/models/research/object_detection/g3doc/FullIJCNN2013/gt_no_jpg.txt'
img_folder = '/media/qing/linux/repo/TF_detection_API/models/research/object_detection/g3doc/FullIJCNN2013'
filename = anno_files

# %%
def int64_feature(value):
    return tf.train.Feature(int64_list=tf.train.Int64List(value=[value]))


def int64_list_feature(value):
    return tf.train.Feature(int64_list=tf.train.Int64List(value=value))


def bytes_feature(value):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=[value]))


def bytes_list_feature(value):
    return tf.train.Feature(bytes_list=tf.train.BytesList(value=value))


def float_list_feature(value):
    return tf.train.Feature(float_list=tf.train.FloatList(value=value))

# %%
# 43class
def create_tf_example(filename, boxes):   
    img = plt.imread(filename)
    with tf.gfile.GFile(filename, 'rb') as fid:
        encoded_jpg = fid.read()
    shape = img.shape
    #im_h, im_w = shape[0], shape[1]
    # TODO(user): Populate the following variables from your example.
    height = shape[0]
    width = shape[1]
    encoded_image_data = img.tostring() # Encoded image bytes
    image_format = b'JPEG'
    
    xmins = []
    xmaxs = []
    
    ymins = []
    ymaxs = []
    
    classes_text = []
    classes = []
    
    for b in boxes:
        xmin,ymin,xmax,ymax,sign_class = b
        xmins.append(xmin/width)
        xmaxs.append(xmax/width)
        ymins.append(ymin/height)
        ymaxs.append(ymax/height)
        
        if sign_class==0:
            classes_text.append('speed_limit_20'.encode('utf8'))
            classes.append(1)
        elif sign_class==1:
            classes_text.append('speed_limit_30'.encode('utf8'))
            classes.append(2)
        elif sign_class==2:
            classes_text.append('speed_limit_50'.encode('utf8'))
            classes.append(3)
        elif sign_class==3:
            classes_text.append('speed_limit_60'.encode('utf8'))
            classes.append(4) 
        elif sign_class==4:
            classes_text.append('speed_limit_70'.encode('utf8'))
            classes.append(5)
        elif sign_class==5:
            classes_text.append('speed_limit_80'.encode('utf8'))
            classes.append(6)
        elif sign_class==6:
            classes_text.append('restriction_ends_80'.encode('utf8'))
            classes.append(7)
        elif sign_class==7:
            classes_text.append('speed_limit_100'.encode('utf8'))
            classes.append(8)
        elif sign_class==8:
            classes_text.append('speed_limit_120'.encode('utf8'))
            classes.append(9)
        elif sign_class==9:
            classes_text.append('no_overtaking'.encode('utf8'))
            classes.append(10)
        elif sign_class==10:
            classes_text.append('no_overtaking_trucks'.encode('utf8'))
            classes.append(11)
        elif sign_class==11:
            classes_text.append('priority_at_next_intersection'.encode('utf8'))
            classes.append(12)
        elif sign_class==12:
            classes_text.append('priority_road'.encode('utf8'))
            classes.append(13)
        elif sign_class==13:
            classes_text.append('give_away'.encode('utf8'))
            classes.append(14)
        elif sign_class==14:
            classes_text.append('stop'.encode('utf8'))
            classes.append(15)
        elif sign_class==15:
            classes_text.append('no_traffic_both_ways'.encode('utf8'))
            classes.append(16)
        elif sign_class==16:
            classes_text.append('no_trucks'.encode('utf8'))
            classes.append(17)
        elif sign_class==17:
            classes_text.append('no_entry'.encode('utf8'))
            classes.append(18)
        elif sign_class==18:
            classes_text.append('danger'.encode('utf8'))
            classes.append(19)
        elif sign_class==19:
            classes_text.append('bend_left'.encode('utf8'))
            classes.append(20)
        elif sign_class==20:
            classes_text.append('bend_right'.encode('utf8'))
            classes.append(21)
        elif sign_class==21:
            classes_text.append('bend'.encode('utf8'))
            classes.append(22)
        elif sign_class==22:
            classes_text.append('uneven_road'.encode('utf8'))
            classes.append(23)
        elif sign_class==23:
            classes_text.append('slippery_road'.encode('utf8'))
            classes.append(24)
        elif sign_class==24:
            classes_text.append('road_narrows'.encode('utf8'))
            classes.append(25)
        elif sign_class==25:
            classes_text.append('construction'.encode('utf8'))
            classes.append(26)
        elif sign_class==26:
            classes_text.append('traffic_signal'.encode('utf8'))
            classes.append(27)
        elif sign_class==27:
            classes_text.append('pedestrian_crossing'.encode('utf8'))
            classes.append(28)
        elif sign_class==28:
            classes_text.append('school_crossing'.encode('utf8'))
            classes.append(29)
        elif sign_class==29:
            classes_text.append('cycles_crossing'.encode('utf8'))
            classes.append(30)
        elif sign_class==30:
            classes_text.append('snow'.encode('utf8'))
            classes.append(31)
        elif sign_class==31:
            classes_text.append('animals'.encode('utf8'))
            classes.append(32)
        elif sign_class==32:
            classes_text.append('restriction_ends'.encode('utf8'))
            classes.append(33)
        elif sign_class==33:
            classes_text.append('go_right'.encode('utf8'))
            classes.append(34)
        elif sign_class==34:
            classes_text.append('go_left'.encode('utf8'))
            classes.append(35)
        elif sign_class==35:
            classes_text.append('go_straight'.encode('utf8'))
            classes.append(36)
        elif sign_class==36:
            classes_text.append('go_right_or_straight'.encode('utf8'))
            classes.append(37)
        elif sign_class==37:
            classes_text.append('go_left_or_straight'.encode('utf8'))
            classes.append(38)
        elif sign_class==38:
            classes_text.append('keep_right'.encode('utf8'))
            classes.append(39)
        elif sign_class==39:
            classes_text.append('keep_left'.encode('utf8'))
            classes.append(40)
        elif sign_class==40:
            classes_text.append('roundabout'.encode('utf8'))
            classes.append(41)
        elif sign_class==41:
            classes_text.append('restriction_ends'.encode('utf8'))
            classes.append(42)
        else: 
            classes_text.append('restriction_ends_trucks'.encode('utf8'))
            classes.append(43)
        
    tf_example = tf.train.Example(features=tf.train.Features(feature={
      'image/height': int64_feature(height),
      'image/width': int64_feature(width),
      'image/filename': bytes_feature(filename.encode('utf8')),
      'image/source_id': bytes_feature(filename.encode('utf8')),
      'image/encoded': bytes_feature(encoded_jpg), ## in here, should use 'encoded_jpg'!!! maybe tfrecord use original format of img.      
      'image/format': bytes_feature('jpeg'.encode('utf8')),
      'image/object/bbox/xmin': float_list_feature(xmins),
      'image/object/bbox/xmax': float_list_feature(xmaxs),
      'image/object/bbox/ymin': float_list_feature(ymins),
      'image/object/bbox/ymax': float_list_feature(ymaxs),
      'image/object/class/text':bytes_list_feature(classes_text),
      'image/object/class/label':int64_list_feature(classes),
    }))
    return tf_example

# %%
# 4 classes, prohibitory, other, danger, mandatory
def create_tf_example(filename, boxes):   
    img = plt.imread(filename)
    with tf.gfile.GFile(filename, 'rb') as fid:
        encoded_jpg = fid.read()
    shape = img.shape
    #im_h, im_w = shape[0], shape[1]
    # TODO(user): Populate the following variables from your example.
    height = shape[0]
    width = shape[1]
    encoded_image_data = img.tostring() # Encoded image bytes
    image_format = b'JPEG'
    
    xmins = []
    xmaxs = []
    
    ymins = []
    ymaxs = []
    
    classes_text = []
    classes = []
    
    for b in boxes:
        xmin,ymin,xmax,ymax,sign_class = b
        xmins.append(xmin/width)
        xmaxs.append(xmax/width)
        ymins.append(ymin/height)
        ymaxs.append(ymax/height)
        
        if sign_class==0:
            classes_text.append('prohibitory'.encode('utf8'))
            classes.append(1)
        elif sign_class==1:
            classes_text.append('prohibitory'.encode('utf8'))
            classes.append(1)
        elif sign_class==2:
            classes_text.append('prohibitory'.encode('utf8'))
            classes.append(1)
        elif sign_class==3:
            classes_text.append('prohibitory'.encode('utf8'))
            classes.append(1) 
        elif sign_class==4:
            classes_text.append('prohibitory'.encode('utf8'))
            classes.append(1)
        elif sign_class==5:
            classes_text.append('prohibitory'.encode('utf8'))
            classes.append(1)
        elif sign_class==6:
            classes_text.append('other'.encode('utf8'))
            classes.append(4)
        elif sign_class==7:
            classes_text.append('prohibitory'.encode('utf8'))
            classes.append(1)
        elif sign_class==8:
            classes_text.append('prohibitory'.encode('utf8'))
            classes.append(1)
        elif sign_class==9:
            classes_text.append('prohibitory'.encode('utf8'))
            classes.append(1)
        elif sign_class==10:
            classes_text.append('prohibitory'.encode('utf8'))
            classes.append(1)
        elif sign_class==11:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==12:
            classes_text.append('other'.encode('utf8'))
            classes.append(4)
        elif sign_class==13:
            classes_text.append('other'.encode('utf8'))
            classes.append(4)
        elif sign_class==14:
            classes_text.append('other'.encode('utf8'))
            classes.append(4)
        elif sign_class==15:
            classes_text.append('prohibitory'.encode('utf8'))
            classes.append(1)
        elif sign_class==16:
            classes_text.append('prohibitory'.encode('utf8'))
            classes.append(1)
        elif sign_class==17:
            classes_text.append('other'.encode('utf8'))
            classes.append(4)
        elif sign_class==18:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==19:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==20:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==21:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==22:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==23:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==24:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==25:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==26:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==27:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==28:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==29:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==30:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==31:
            classes_text.append('danger'.encode('utf8'))
            classes.append(3)
        elif sign_class==32:
            classes_text.append('other'.encode('utf8'))
            classes.append(4)
        elif sign_class==33:
            classes_text.append('mandatory'.encode('utf8'))
            classes.append(2)
        elif sign_class==34:
            classes_text.append('mandatory'.encode('utf8'))
            classes.append(2)
        elif sign_class==35:
            classes_text.append('mandatory'.encode('utf8'))
            classes.append(2)
        elif sign_class==36:
            classes_text.append('mandatory'.encode('utf8'))
            classes.append(2)
        elif sign_class==37:
            classes_text.append('mandatory'.encode('utf8'))
            classes.append(2)
        elif sign_class==38:
            classes_text.append('mandatory'.encode('utf8'))
            classes.append(2)
        elif sign_class==39:
            classes_text.append('mandatory'.encode('utf8'))
            classes.append(2)
        elif sign_class==40:
            classes_text.append('mandatory'.encode('utf8'))
            classes.append(2)
        elif sign_class==41:
            classes_text.append('other'.encode('utf8'))
            classes.append(4)
        else: 
            classes_text.append('other'.encode('utf8'))
            classes.append(4)
        
    tf_example = tf.train.Example(features=tf.train.Features(feature={
      'image/height': int64_feature(height),
      'image/width': int64_feature(width),
      'image/filename': bytes_feature(filename.encode('utf8')),
      'image/source_id': bytes_feature(filename.encode('utf8')),
      'image/encoded': bytes_feature(encoded_jpg), ## in here, should use 'encoded_jpg'!!! maybe tfrecord use original format of img.      
      'image/format': bytes_feature('jpeg'.encode('utf8')),
      'image/object/bbox/xmin': float_list_feature(xmins),
      'image/object/bbox/xmax': float_list_feature(xmaxs),
      'image/object/bbox/ymin': float_list_feature(ymins),
      'image/object/bbox/ymax': float_list_feature(ymaxs),
      'image/object/class/text':bytes_list_feature(classes_text),
      'image/object/class/label':int64_list_feature(classes),
    }))
    return tf_example

# %%
# worry_format 
def create_tf_example(filename, boxes):   
    img = plt.imread(filename)
    #shape = img.shape
    #im_h, im_w = shape[0], shape[1]
    # TODO(user): Populate the following variables from your example.
    height = img.shape[0]
    width = img.shape[1]
    encoded_image_data = img.tostring() # Encoded image bytes
    #encoded_image_data = tf.Session().run(img)
    image_format = b'jpeg'
    
    xmins = []
    xmaxs = []
    
    ymins = []
    ymaxs = []
    
    classes_text = []
    classes = []
    
    for b in boxes:
        xmin,ymin,xmax,ymax,sign_class = b
        xmins.append(xmin/width)
        xmaxs.append(xmax/width)
        ymins.append(ymin/height)
        ymaxs.append(ymax/height)
        #classes_text.append(classname[sign_class])
        
        classes_text.append('traffic_sign'.encode('utf8'))
        #classes.append(sign_class+1)
        classes.append(1)
        
    tf_example = tf.train.Example(features=tf.train.Features(feature={
      'image/height': int64_feature(height),
      'image/width': int64_feature(width),
      'image/filename': bytes_feature(filename.encode('utf8')),
      'image/source_id': bytes_feature(filename.encode('utf8')),
      'image/encoded': bytes_feature(encoded_image_data),
      'image/format': bytes_feature(image_format),
      'image/object/bbox/xmin': float_list_feature(xmins),
      'image/object/bbox/xmax': float_list_feature(xmaxs),
      'image/object/bbox/ymin': float_list_feature(ymins),
      'image/object/bbox/ymax': float_list_feature(ymaxs),
      'image/object/class/text':bytes_list_feature(classes_text),
      'image/object/class/label':int64_list_feature(classes),
    }))
    return tf_example

# %%
# path different
# if want to separate dataset in 3 group, run this block
# train dataset
tfrecords_filename_train = 'train_class4.tfrecords'
writer_train = tf.python_io.TFRecordWriter(tfrecords_filename_train)
# val dataset(API dont need 'val')
#tfrecords_filename_val = 'val20.tfrecords'
#writer_val = tf.python_io.TFRecordWriter(tfrecords_filename_val)
# test dataset
tfrecords_filename_test = 'test_class_4.tfrecords'
writer_test = tf.python_io.TFRecordWriter(tfrecords_filename_test)

original_images = []
last_filename = '00000'
n = 0
counter = -1
boxes = []
# root_folder = '/media/qing/linux/repo/TF_detection_API/models/research/object_detection/g3doc/FullIJCNN2013/'

with open(filename, 'r') as f:
    while(1):
        line = f.readline()        
        if not line:
            break
        line_split = line.split(';')    
        img_file = line_split[0]
        x1, x2, y1, y2 = line_split[1:5]
        sign_class =line_split[5]
        #print(img_file, x1, x2, y1, y2, sign_class )  #eg. FullIJCNN2013/00000.ppm
        
        if (img_file != last_filename):
            counter += 1
            print(n,last_filename,img_file, counter)
            tf_example = create_tf_example(last_filename,boxes) 
            if (counter%10<8):
                writer_train.write(tf_example.SerializeToString())
                print('train_class43.tfrecords')
            #elif (counter%10==6 or counter%10==7):
            #    writer_val.write(tf_example.SerializeToString())
            #    print('val.tfrecords')
            else:
                writer_test.write(tf_example.SerializeToString())
                print('test_class43.tfrecords')
            #tf_example = create_tf_example('FullIJCNN2013/'+last_filename,boxes) 
            #tf_example = create_tf_example(root_folder+last_filename,boxes) 
            #writer.write(tf_example.SerializeToString())
            last_filename = img_file
            boxes = []      
        
        boxes.append([float(x1),float(x2),float(y1),float(y2),int(sign_class)])
        n+=1
        if n==1214:break
writer_train.close()
#writer_val.close()
writer_test.close()
#writer.close
# Out:
# 1 00000 00001 0
# train_class43.tfrecords
# 4 00001 00002 1
# train_class43.tfrecords
# 5 00002 00003 2
# train_class43.tfrecords
# 8 00003 00004 3
# train_class43.tfrecords
# 10 00004 00005 4
# train_class43.tfrecords
# 11 00005 00006 5
# train_class43.tfrecords
# 12 00006 00007 6
# train_class43.tfrecords
# 13 00007 00008 7
# train_class43.tfrecords
# 15 00008 00009 8
# test_class43.tfrecords
# 16 00009 00010 9
# test_class43.tfrecords
# 17 00010 00011 10
# train_class43.tfrecords
# 19 00011 00012 11
# train_class43.tfrecords
# 20 00012 00013 12
# train_class43.tfrecords
# 21 00013 00014 13
# train_class43.tfrecords
# 22 00014 00015 14
# train_class43.tfrecords
# 23 00015 00016 15
# train_class43.tfrecords
# 24 00016 00017 16
# train_class43.tfrecords
# 26 00017 00018 17
# train_class43.tfrecords
# 27 00018 00019 18
# test_class43.tfrecords
# 29 00019 00020 19
# test_class43.tfrecords
# 30 00020 00021 20
# train_class43.tfrecords
# 31 00021 00022 21
# train_class43.tfrecords
# ...

# %%
# path different
# if want to separate dataset in 3 group, run this block
# train dataset
tfrecords_filename_train = 'train.tfrecords'
writer_train = tf.python_io.TFRecordWriter(tfrecords_filename_train)
# val dataset
tfrecords_filename_val = 'val.tfrecords'
writer_val = tf.python_io.TFRecordWriter(tfrecords_filename_val)
# test dataset
tfrecords_filename_test = 'test.tfrecords'
writer_test = tf.python_io.TFRecordWriter(tfrecords_filename_test)

original_images = []
last_filename = '00000'
n = 0
counter = -1
boxes = []
# root_folder = '/media/qing/linux/repo/TF_detection_API/models/research/object_detection/g3doc/FullIJCNN2013/'

with open(filename, 'r') as f:
    while(1):
        line = f.readline()        
        if not line:
            break
        line_split = line.split(';')    
        img_file = line_split[0]
        x1, x2, y1, y2 = line_split[1:5]
        sign_class =line_split[5]
        #print(img_file, x1, x2, y1, y2, sign_class )  #eg. FullIJCNN2013/00000.ppm
        
        if (img_file != last_filename):
            counter += 1
            print(n,last_filename,img_file, counter)
            tf_example = create_tf_example(last_filename,boxes) 
            if (counter%10<6):
                writer_train.write(tf_example.SerializeToString())
                print('train.tfrecords')
            elif (counter%10==6 or counter%10==7):
                writer_val.write(tf_example.SerializeToString())
                print('val.tfrecords')
            else:
                writer_test.write(tf_example.SerializeToString())
                print('test.tfrecords')
            #tf_example = create_tf_example('FullIJCNN2013/'+last_filename,boxes) 
            #tf_example = create_tf_example(root_folder+last_filename,boxes) 
            #writer.write(tf_example.SerializeToString())
            last_filename = img_file
            boxes = []      
        
        boxes.append([float(x1),float(x2),float(y1),float(y2),int(sign_class)])
        n+=1
        if n==1213:break
writer_train.close()
writer_val.close()
writer_test.close()
# Out:
# 1 00000 00001 0
# train.tfrecords
# 4 00001 00002 1
# train.tfrecords
# 5 00002 00003 2
# train.tfrecords
# 8 00003 00004 3
# train.tfrecords
# 10 00004 00005 4
# train.tfrecords
# 11 00005 00006 5
# train.tfrecords
# 12 00006 00007 6
# val.tfrecords
# 13 00007 00008 7
# val.tfrecords
# 15 00008 00009 8
# test.tfrecords
# 16 00009 00010 9
# test.tfrecords
# 17 00010 00011 10
# train.tfrecords
# 19 00011 00012 11
# train.tfrecords
# 20 00012 00013 12
# train.tfrecords
# 21 00013 00014 13
# train.tfrecords
# 22 00014 00015 14
# train.tfrecords
# 23 00015 00016 15
# train.tfrecords
# 24 00016 00017 16
# val.tfrecords
# 26 00017 00018 17
# val.tfrecords
# 27 00018 00019 18
# test.tfrecords
# 29 00019 00020 19
# test.tfrecords
# 30 00020 00021 20
# train.tfrecords
# 31 00021 00022 21
# train.tfrecords
# 32 00022 00023 22
# train.tfrecords
# 35 00023 00024 23
# train.tfrecords
# 36 00024 00025 24
# train.tfrecords
# 38 00025 00026 25
# train.tfrecords
# 39 00026 00027 26
# val.tfrecords
# ...
